# %% [markdown]
# # Conditions

# %%
age = 18
if age > 18:
    print("Vous êtes majeur")

# %%
if age >= 18:
    print("Vous êtes majeur")
# Out:
# Vous êtes majeur

# %% [markdown]
# ## Test : évaluer une expression Python

# %%
print(age > 18)
# Out:
# False

# %%
print(age >= 18)
# Out:
# True

# %%
if True:
    print("Cela s'exécute toujours")
# Out:
# Cela s'exécute toujours

# %%
if False:
    print("Va t-il s'exécuter ?")

# %% [markdown]
# ## Les opérateurs Python
# ![image.png](attachment:5b752086-9635-45f7-9c4d-e51eff069961.png)

# %%
print(age == 18)
# Out:
# True

# %%
print(age != 18)
# Out:
# False

# %%
print("Hello" == "HELLO")
# Out:
# False

# %% [markdown]
# ## Indentation en Python

# %%
if age == 18:
    print("Vrai")
# Out:
# Vrai

# %%
if age == 18:
print("Vrai")
# Out:
#   Cell In[11], line 2
#     print("Vrai")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if age == 18:
 print("Vrai")
# Out:
# Vrai

# %% [markdown]
# L'indendation c'est soit une tabulation ou 4 caractères.

# %% [markdown]
# # Indentations imbriquées

# %%
if age == 18:
    if age >= 18:
        print("Hello")
# Out:
# Hello
